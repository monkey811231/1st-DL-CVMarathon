# %%
pip install xmltodict
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xmltodict
#請問高雄市有多少地區有溫度資料？
with open('./data/sample.xml','r',encoding='utf-8') as f :
    print(f.read())
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <CUPOY>
#     <Title>爬蟲馬拉松</Title>
#     <Author>Wei</Author>
#     <Chapters>
#         <Chapter name="01">資料來源與存取</Chapter>
#         <Chapter name="02">靜態網頁爬蟲</Chapter>
#         <Chapter name="03">動態網頁爬蟲</Chapter>
#     </Chapters>
# </CUPOY>

# %%
with open('./data/sample.xml','r',encoding='utf-8') as f :
    doc = xmltodict.parse(f.read())
    print(doc)
    print('==============')
    print(doc['CUPOY'])
    print('==============')
    print(doc['CUPOY']['Title'])
    aa = doc['CUPOY']['Chapters']['Chapter']
    print(aa)
    for i in aa :
        print('====')
        print(i['@name'],i['#text'])
# Out:
# OrderedDict([('CUPOY', OrderedDict([('Title', '爬蟲馬拉松'), ('Author', 'Wei'), ('Chapters', OrderedDict([('Chapter', [OrderedDict([('@name', '01'), ('#text', '資料來源與存取')]), OrderedDict([('@name', '02'), ('#text', '靜態網頁爬蟲')]), OrderedDict([('@name', '03'), ('#text', '動態網頁爬蟲')])])]))]))])
# ...
# OrderedDict([('Title', '爬蟲馬拉松'), ('Author', 'Wei'), ('Chapters', OrderedDict([('Chapter', [OrderedDict([('@name', '01'), ('#text', '資料來源與存取')]), OrderedDict([('@name', '02'), ('#text', '靜態網頁爬蟲')]), OrderedDict([('@name', '03'), ('#text', '動態網頁爬蟲')])])]))])
# ...
# 爬蟲馬拉松
# [OrderedDict([('@name', '01'), ('#text', '資料來源與存取')]), OrderedDict([('@name', '02'), ('#text', '靜態網頁爬蟲')]), OrderedDict([('@name', '03'), ('#text', '動態網頁爬蟲')])]
# ====
# 01 資料來源與存取
# ====
# 02 靜態網頁爬蟲
# ====
# 03 動態網頁爬蟲

# %%
# 1. 請問高雄市有多少地區有溫度資料？
with open('./data/64_72hr_CH.xml','r',encoding="utf-8") as f :
#     print(f.read())  #用IO看

    doc = xmltodict.parse(f.read())
    print('==============')
    locations = doc['cwbopendata']['dataset']['locations']['location']
    print('高雄共有{}個地區有溫度資料'.format(len(locations)))
    
    for i in locations :
        print(i['locationName'])
# Out:
# ...
# 高雄共有38個地區有溫度資料
# 鹽埕區
# 鼓山區
# 左營區
# 楠梓區
# 三民區
# 新興區
# 前金區
# 苓雅區
# 前鎮區
# 旗津區
# 小港區
# 鳳山區
# 林園區
# 大寮區
# 大樹區
# 大社區
# 仁武區
# 鳥松區
# 岡山區
# 橋頭區
# 燕巢區
# 田寮區
# 阿蓮區
# 路竹區
# 湖內區
# 茄萣區
# 永安區
# 彌陀區
# 梓官區
# 旗山區
# 美濃區
# 六龜區
# 甲仙區
# 杉林區
# 內門區
# 茂林區
# 桃源區
# 那瑪夏區

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
with open('./data/64_72hr_CH.xml','r',encoding="utf-8") as f :
#     print(f.read())
    doc = xmltodict.parse(f.read())
#     print(doc)
    locations = doc['cwbopendata']['dataset']['locations']['location']
    for i in locations :
        locationname = i['locationName']
#         print(i)
        locationdatatime = i['weatherElement'][0]['time'][0]['dataTime'].split('+')[0]
        locationTemp = i['weatherElement'][0]['time'][1]['elementValue']['value']
        
        print(f'地區 : {locationname}   \n\t第一紀錄時間/溫度 : {locationdatatime}  /  {locationTemp}度C\n')
# Out:
# 地區 : 鹽埕區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  33度C
#
# 地區 : 鼓山區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  33度C
#
# 地區 : 左營區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  33度C
#
# 地區 : 楠梓區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  34度C
#
# 地區 : 三民區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  33度C
#
# 地區 : 新興區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  33度C
#
# 地區 : 前金區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  33度C
#
# 地區 : 苓雅區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  33度C
#
# 地區 : 前鎮區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  33度C
#
# 地區 : 旗津區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  32度C
#
# 地區 : 小港區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  33度C
#
# 地區 : 鳳山區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  34度C
#
# 地區 : 林園區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  34度C
#
# 地區 : 大寮區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  34度C
#
# 地區 : 大樹區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  34度C
#
# 地區 : 大社區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  34度C
#
# 地區 : 仁武區
# 	第一紀錄時間/溫度 : 2019-06-28T12:00:00  /  34度C
#
# 地區 : 鳥松區
# ...

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度
with open('./data/64_72hr_CH.xml','r',encoding="utf-8") as f :
#     print(f.read())
    doc = xmltodict.parse(f.read())
#     print(doc)
    locations = doc['cwbopendata']['dataset']['locations']['location'][0]
    print(locations['locationName'])
    for i in locations['weatherElement']:
        
        for j in i['time'] :
#             print(j)
            try:
                time = j['dataTime'].split('+')[0]
                temp = j['elementValue']['value']
                
                print(f'日期時間 : {time} \n\t 攝氏溫度 : {temp}度')
            except:
                pass
# Out:
# 鹽埕區
# 日期時間 : 2019-06-28T12:00:00
# 	 攝氏溫度 : 33度
# 日期時間 : 2019-06-28T15:00:00
# 	 攝氏溫度 : 33度
# 日期時間 : 2019-06-28T18:00:00
# 	 攝氏溫度 : 32度
# 日期時間 : 2019-06-28T21:00:00
# 	 攝氏溫度 : 30度
# 日期時間 : 2019-06-29T00:00:00
# 	 攝氏溫度 : 30度
# 日期時間 : 2019-06-29T03:00:00
# 	 攝氏溫度 : 29度
# 日期時間 : 2019-06-29T06:00:00
# 	 攝氏溫度 : 28度
# 日期時間 : 2019-06-29T09:00:00
# 	 攝氏溫度 : 31度
# 日期時間 : 2019-06-29T12:00:00
# 	 攝氏溫度 : 32度
# 日期時間 : 2019-06-29T15:00:00
# 	 攝氏溫度 : 32度
# 日期時間 : 2019-06-29T18:00:00
# 	 攝氏溫度 : 31度
# 日期時間 : 2019-06-29T21:00:00
# 	 攝氏溫度 : 30度
# 日期時間 : 2019-06-30T00:00:00
# 	 攝氏溫度 : 29度
# 日期時間 : 2019-06-30T03:00:00
# 	 攝氏溫度 : 28度
# 日期時間 : 2019-06-30T06:00:00
# 	 攝氏溫度 : 28度
# 日期時間 : 2019-06-30T09:00:00
# 	 攝氏溫度 : 31度
# 日期時間 : 2019-06-30T12:00:00
# 	 攝氏溫度 : 32度
# 日期時間 : 2019-06-30T15:00:00
# 	 攝氏溫度 : 32度
# 日期時間 : 2019-06-30T18:00:00
# 	 攝氏溫度 : 31度
# 日期時間 : 2019-06-30T21:00:00
# 	 攝氏溫度 : 30度
# 日期時間 : 2019-07-01T00:00:00
# 	 攝氏溫度 : 29度
# 日期時間 : 2019-07-01T03:00:00
# 	 攝氏溫度 : 29度
# ...
